# %% [markdown]
# # Identifying Pneumonia In Pediatric Chest X-Rays With Neural Networks
#
# ### Authors: Eric Denbin & Jesse Markowitz

# %% [markdown]
# ![healthy vs penumonia cxr](images/healthy_vs_pneumonia_cxr.png)

# %%
# Load dependencies
import os, shutil
import datetime
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import matplotlib.image as mpimg
import keras
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras import models
from keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, Flatten, Activation, BatchNormalization
from keras.regularizers import l2
from keras.optimizers import Adam, SGD
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.utils import class_weight

from project_functions import get_images, preprocess_dense_data, preprocess_cnn_data, visualize_results_cnn,\
                                 visualize_training_results, get_class_weights, cnn_model

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Business Understanding

# %% [markdown]
# Pneumonia is the presence of liquid in the lungs as a result of bacterial or viral infection. It is the leading cause of death in children under 5, accounting for 19% of all deaths worldwide in that age range.
#
# Pneumonia can also be difficult to diagnose as there is no "gold standard" indication for it. Medical professionals use a combination of symptoms and scans, such as chest x-rays (CXR) to make a positive diagnosis.

# %% [markdown]
# <img src="images/infographic-pediatricpneumonia.jpg" alt="pneumonia infographic from WHO" width="400"/>

# %% [markdown]
# Scans can be ambiguous and difficult to interpret, presenting another source of error. According to a study in the Journal of the American Academy of Pediatrics, 8.9% of children with a negative CXR were nonetheless diagnosed with pneumonia ([source](https://pediatrics.aappublications.org/content/142/3/e20180236)). This means that the doctors in the study correctly diagnosed patients with pneumonia 91.1% of the time. This postive identification rate is known in the medical community as "sensitivity" and in the data science community as "recall." We are using recall as our primary metric for success because we want to avoid labeling unhealthy patients as healthy.
#
# This presents a good use case for machine learning image classification models. By training a model to identify CXRs that present positive for pneumonia, we can provide a consistent and powerful tool for medical professionals to use as part of their diagnostic toolkit.

# %% [markdown]
# ## Data Understanding

# %% [markdown]
# Our dataset consists of 5,863 pediatric chest radiographs (X-ray images) from the Guangzhou Women and Children's Medical Center, via [Kaggle](https://www.kaggle.com/paultimothymooney/chest-xray-pneumonia). All patients were 1-5 years old and the chest x-rays were taken in the course of routine care.
#
# The images are stored in Training and Test folders, then split again into Normal and Pneumonia folders. This file structure provides the ground truth labeling needed to train our models:
# ```
# └── chest_xray
#     ├── train
#     │    ├──NORMAL
#     │    └──PNEUMONIA
#     └── test
#          ├──NORMAL
#          └──PNEUMONIA
# ```

# %% [markdown]
# ### Load the data

# %% [markdown]
# The original `val` folder from Kaggle contained only 8 images *each* from Normal and Pneumonia, which is not a sufficient size for validation.
#
# Rather than adding files to that folder to increase the size of the validation set, we have chosen to move **all** images into the `train` folder. We will then use the `val_split` parameter in `flow_from_directory` to instantiate a validation set.

# %%
# Filepaths
train_dir = 'chest_xray/train'
test_dir = 'chest_xray/test/'

# %%
# Check functionality and num images
train_normal_dir = os.path.join(train_dir, 'NORMAL')
train_pneumonia_dir = os.path.join(train_dir, 'PNEUMONIA')
train_normal_dir
# Out:
# 'chest_xray/train/NORMAL'

# %%
# Delete metadata files created by Mac OS
# !find . -name ".DS_Store" -delete

# %%
# Check number of files; should be 1349 normal and 3883 pneumonia images in the training set
print('There are', len(os.listdir(train_normal_dir)), 'normal images in the training set')
print('There are', len(os.listdir(train_pneumonia_dir)), 'pneumonia images in the training set')
# Out:
# There are 1349 normal images in the training set
# There are 3883 pneumonia images in the training set

# %%
# Get list of filenames of all training images
train_norm_filenames = os.listdir(train_normal_dir)
train_pneum_filenames = os.listdir(train_pneumonia_dir)

# %%
# Make list of full filepaths to each image
train_normal_filepaths = [os.path.join(train_normal_dir, name) for name in train_norm_filenames]
train_pneumonia_filepaths = [os.path.join(train_pneumonia_dir, name) for name in train_pneum_filenames]
train_normal_filepaths[:5]
# Out:
# ['chest_xray/train/NORMAL/NORMAL2-IM-0927-0001.jpeg',
#  'chest_xray/train/NORMAL/NORMAL2-IM-1056-0001.jpeg',
#  'chest_xray/train/NORMAL/IM-0427-0001.jpeg',
#  'chest_xray/train/NORMAL/NORMAL2-IM-1260-0001.jpeg',
#  'chest_xray/train/NORMAL/IM-0656-0001-0001.jpeg']

# %%
# Get training images of normal and pneumonia
# Read each file in as an image
train_normal_images = get_images(train_normal_dir)
train_pneumonia_images = get_images(train_pneumonia_dir)

# %%
# Visualize class distribution in training data
total_images = len(train_normal_images) + len(train_pneumonia_images)
fig, ax = plt.subplots(figsize=(8, 8))

ax.bar(x=['Normal', 'Pneumonia'], height=[len(train_normal_images)/total_images, 
                                                  len(train_pneumonia_images)/total_images])
ax.set_title('Class Distribution in Training Data', size=15)
ax.set_ylabel('Percentage of Dataset', size=13)
ax.set_xlabel('X-Ray Image Class', size=13)
ax.set_yticklabels([str(int(p*100))+'%' for p in ax.get_yticks()])
plt.show()
# Out:
# <ipython-input-17-9411ddf175ee>:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([str(int(p*100))+'%' for p in ax.get_yticks()])

# %% [markdown]
# There is an over-representation of target class images in the data, which may present an issue during modeling. We will experiment with adding in parameters to account for this, such as `class_weight`, as the current distribution is about 3:1 in favor of the target class (23% Normal, 77% Pneumonia).

# %% [markdown]
# ## Data Preparation and EDA

# %% [markdown]
# ### EDA: Image Samples and Metadata

# %% [markdown]
# #### Show the first 5 images from each set:

# %%
fig, axs = plt.subplots(1, 5, figsize=(20, 5))

for i, ax in enumerate(axs):
    ax.imshow(train_normal_images[i], cmap='gray')
fig.suptitle('Normal Lungs', fontsize=15, y=.8)
fig.tight_layout;

# %%
fig, axs = plt.subplots(1, 5, figsize=(20, 5))

for i, ax in enumerate(axs):
    ax.imshow(train_pneumonia_images[i], cmap='gray')
fig.suptitle('Lungs With Pneumonia', fontsize=15, y=.8)
fig.tight_layout;

# %% [markdown]
# All images are single-channel (black and white, not RGB) and almost all have an 'R' to designate the right-hand side lung. Typically, pneumonia lungs look "cloudy" or "fuzzy" compared to Normal

# %% [markdown]
# From Kaggle:
# > The normal chest X-ray (left panel) depicts clear lungs without any areas of abnormal opacification in the image. Bacterial pneumonia (middle) typically exhibits a focal lobar consolidation, in this case in the right upper lobe (white arrows), whereas viral pneumonia (right) manifests with a more diffuse ‘‘interstitial’’ pattern in both lungs.
#
# Essentially, this means that bacterial pneumonia typically gathers in one area of the lungs, while viral penumonia is more spread out.

# %% [markdown]
# #### Metadata

# %%
# Dimensions of images
normal_img_shapes = [img.shape for img in train_normal_images]
pneumonia_img_shapes = [img.shape for img in train_pneumonia_images]

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 6))

# Sizes of Normal lung images
ax1.scatter(x=[x[0] for x in normal_img_shapes], y=[x[1] for x in normal_img_shapes])
ax1.set_title('Dimensions of Normal lung images')

# Sizes of Pneumonia lung images
ax2.scatter(x=[x[0] for x in pneumonia_img_shapes], y=[x[1] for x in pneumonia_img_shapes])
ax2.set_title('Dimensions of Pneumonia lung images');

# %%
print('Smallest normal image dimension is ', np.min(normal_img_shapes))
print('Largest normal image dimension is ', np.max(normal_img_shapes))
print('Smallest pneumonia image dimension is ', np.min(pneumonia_img_shapes))
print('Largest pneumonia image dimension is ', np.max(pneumonia_img_shapes))
# Out:
# Smallest normal image dimension is  672
# Largest normal image dimension is  2916
# Smallest pneumonia image dimension is  (127, 384, 3)
# Largest pneumonia image dimension is  (2304, 2160)

# %% [markdown]
# The linear relationships suggest similar aspect ratios, especially with smaller images (more variety with larger size images). However, there is a large variety in terms of image size. The largest images are over 3x the size of the smallest images! We will resize images during modeling using the `'target_size'` parameter in the `flow_from_directory` method with Keras image generators.

# %% [markdown]
# ## Modeling with neural networks

# %% [markdown]
# We'll use the `ImageDataGenerator` class from Keras, as well as `flow_from_directory` to access the images and create our training and validation sets.

# %% [markdown]
# ### First simple model

# %% [markdown]
# Our FSM consists of a basic fully connected dense neural network with only 1 hidden layer, plus an output layer. We'll reduce the image size to 100x100 pixels and feed in only 50 images. This model serves mainly as a proof of concept and provides baseline accuracy and recall scores.

# %%
# Load in data with a validation split of 20%
X_train, X_val, train_labels, val_labels = preprocess_dense_data(train_dir,
                                                                 target_size=(100, 100), 
                                                                 batch_size=50)
# Out:
# Found 4187 images belonging to 2 classes.
# Found 1045 images belonging to 2 classes.

# %%
# Instatiate model
fsm = models.Sequential()

# Add model layers
fsm.add(Dense(32, activation='relu', input_shape=(10000,)))
fsm.add(Dense(1, activation='sigmoid'))

# Compile
fsm.compile(optimizer='sgd',
            loss='binary_crossentropy',
            metrics=['acc', 'Recall'])

# %%
# Train the model
history = fsm.fit(X_train, train_labels, 
                  epochs=50,
                  batch_size=10,
                  validation_data=(X_val, val_labels))
# Out:
# Epoch 1/50
# 5/5 [==============================] - 0s 66ms/step - loss: 0.7861 - acc: 0.7200 - recall: 0.8421 - val_loss: 0.5301 - val_acc: 0.7800 - val_recall: 1.0000
# Epoch 2/50
# 5/5 [==============================] - 0s 8ms/step - loss: 0.5648 - acc: 0.7600 - recall: 1.0000 - val_loss: 0.5302 - val_acc: 0.7800 - val_recall: 1.0000
# Epoch 3/50
# 5/5 [==============================] - 0s 8ms/step - loss: 0.6096 - acc: 0.7600 - recall: 1.0000 - val_loss: 0.4879 - val_acc: 0.7800 - val_recall: 1.0000
# Epoch 4/50
# 5/5 [==============================] - 0s 8ms/step - loss: 0.5772 - acc: 0.7600 - recall: 1.0000 - val_loss: 0.5018 - val_acc: 0.7800 - val_recall: 1.0000
# Epoch 5/50
# 5/5 [==============================] - 0s 7ms/step - loss: 0.5401 - acc: 0.7600 - recall: 1.0000 - val_loss: 0.5302 - val_acc: 0.7800 - val_recall: 1.0000
# Epoch 6/50
# 5/5 [==============================] - 0s 7ms/step - loss: 0.5053 - acc: 0.7600 - recall: 1.0000 - val_loss: 0.4716 - val_acc: 0.7800 - val_recall: 1.0000
# Epoch 7/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5006 - acc: 0.7600 - recall: 1.0000 - val_loss: 0.4810 - val_acc: 0.7800 - val_recall: 1.0000
# Epoch 8/50
# 5/5 [==============================] - 0s 8ms/step - loss: 0.5301 - acc: 0.7600 - recall: 1.0000 - val_loss: 0.4604 - val_acc: 0.7800 - val_recall: 1.0000
# Epoch 9/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.5043 - acc: 0.7600 - recall: 1.0000 - val_loss: 0.4428 - val_acc: 0.7800 - val_recall: 1.0000
# Epoch 10/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.4927 - acc: 0.7600 - recall: 1.0000 - val_loss: 0.4351 - val_acc: 0.7800 - val_recall: 1.0000
# Epoch 11/50
# 5/5 [==============================] - 0s 7ms/step - loss: 0.4429 - acc: 0.7600 - recall: 1.0000 - val_loss: 0.4774 - val_acc: 0.7800 - val_recall: 1.0000
# Epoch 12/50
# 5/5 [==============================] - 0s 8ms/step - loss: 0.4615 - acc: 0.7600 - recall: 1.0000 - val_loss: 0.4384 - val_acc: 0.7800 - val_recall: 1.0000
# Epoch 13/50
# 5/5 [==============================] - 0s 7ms/step - loss: 0.4619 - acc: 0.7600 - recall: 1.0000 - val_loss: 0.4139 - val_acc: 0.7800 - val_recall: 1.0000
# Epoch 14/50
# 5/5 [==============================] - 0s 7ms/step - loss: 0.4429 - acc: 0.7600 - recall: 1.0000 - val_loss: 0.4955 - val_acc: 0.7800 - val_recall: 1.0000
# Epoch 15/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.4555 - acc: 0.7600 - recall: 1.0000 - val_loss: 0.4053 - val_acc: 0.7800 - val_recall: 1.0000
# Epoch 16/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3934 - acc: 0.7600 - recall: 1.0000 - val_loss: 0.4623 - val_acc: 0.7800 - val_recall: 1.0000
# Epoch 17/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.4761 - acc: 0.7800 - recall: 1.0000 - val_loss: 0.4031 - val_acc: 0.7800 - val_recall: 1.0000
# Epoch 18/50
# 5/5 [==============================] - 0s 8ms/step - loss: 0.3854 - acc: 0.7600 - recall: 1.0000 - val_loss: 0.3898 - val_acc: 0.7800 - val_recall: 1.0000
# Epoch 19/50
# 5/5 [==============================] - 0s 7ms/step - loss: 0.4113 - acc: 0.7800 - recall: 1.0000 - val_loss: 0.3791 - val_acc: 0.7800 - val_recall: 1.0000
# Epoch 20/50
# 5/5 [==============================] - 0s 8ms/step - loss: 0.4404 - acc: 0.8000 - recall: 1.0000 - val_loss: 0.4472 - val_acc: 0.8200 - val_recall: 1.0000
# Epoch 21/50
# 5/5 [==============================] - 0s 7ms/step - loss: 0.3709 - acc: 0.8000 - recall: 1.0000 - val_loss: 0.3739 - val_acc: 0.8000 - val_recall: 1.0000
# Epoch 22/50
# 5/5 [==============================] - 0s 7ms/step - loss: 0.4097 - acc: 0.7800 - recall: 1.0000 - val_loss: 0.3913 - val_acc: 0.8200 - val_recall: 1.0000
# Epoch 23/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.3598 - acc: 0.8000 - recall: 1.0000 - val_loss: 0.3664 - val_acc: 0.7800 - val_recall: 1.0000
# Epoch 24/50
# 5/5 [==============================] - 0s 8ms/step - loss: 0.3765 - acc: 0.8200 - recall: 1.0000 - val_loss: 0.4047 - val_acc: 0.7800 - val_recall: 1.0000
# Epoch 25/50
# 5/5 [==============================] - 0s 7ms/step - loss: 0.3536 - acc: 0.8000 - recall: 1.0000 - val_loss: 0.3546 - val_acc: 0.8000 - val_recall: 1.0000
# Epoch 26/50
# 5/5 [==============================] - 0s 7ms/step - loss: 0.3627 - acc: 0.8000 - recall: 1.0000 - val_loss: 0.3639 - val_acc: 0.7800 - val_recall: 1.0000
# Epoch 27/50
# 5/5 [==============================] - 0s 7ms/step - loss: 0.3516 - acc: 0.8000 - recall: 1.0000 - val_loss: 0.3939 - val_acc: 0.7800 - val_recall: 1.0000
# Epoch 28/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.4149 - acc: 0.8400 - recall: 1.0000 - val_loss: 0.3724 - val_acc: 0.7800 - val_recall: 1.0000
# Epoch 29/50
# 5/5 [==============================] - 0s 7ms/step - loss: 0.3773 - acc: 0.8000 - recall: 1.0000 - val_loss: 0.3557 - val_acc: 0.8000 - val_recall: 1.0000
# Epoch 30/50
# 5/5 [==============================] - 0s 7ms/step - loss: 0.3037 - acc: 0.8400 - recall: 1.0000 - val_loss: 0.3462 - val_acc: 0.8400 - val_recall: 1.0000
# Epoch 31/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.3161 - acc: 0.8600 - recall: 1.0000 - val_loss: 0.3632 - val_acc: 0.8000 - val_recall: 1.0000
# Epoch 32/50
# 5/5 [==============================] - 0s 7ms/step - loss: 0.3656 - acc: 0.8400 - recall: 1.0000 - val_loss: 0.3334 - val_acc: 0.8200 - val_recall: 1.0000
# Epoch 33/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.3017 - acc: 0.8600 - recall: 1.0000 - val_loss: 0.3657 - val_acc: 0.8000 - val_recall: 1.0000
# Epoch 34/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.3375 - acc: 0.8600 - recall: 1.0000 - val_loss: 0.3329 - val_acc: 0.8000 - val_recall: 1.0000
# Epoch 35/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.2757 - acc: 0.8200 - recall: 1.0000 - val_loss: 0.4229 - val_acc: 0.9000 - val_recall: 0.9231
# Epoch 36/50
# 5/5 [==============================] - 0s 7ms/step - loss: 0.3476 - acc: 0.9000 - recall: 1.0000 - val_loss: 0.3419 - val_acc: 0.8400 - val_recall: 1.0000
# Epoch 37/50
# 5/5 [==============================] - 0s 7ms/step - loss: 0.3316 - acc: 0.8400 - recall: 1.0000 - val_loss: 0.3197 - val_acc: 0.8600 - val_recall: 1.0000
# Epoch 38/50
# 5/5 [==============================] - 0s 8ms/step - loss: 0.2874 - acc: 0.8800 - recall: 1.0000 - val_loss: 0.3199 - val_acc: 0.8200 - val_recall: 1.0000
# Epoch 39/50
# 5/5 [==============================] - 0s 7ms/step - loss: 0.2727 - acc: 0.8600 - recall: 1.0000 - val_loss: 0.3200 - val_acc: 0.8600 - val_recall: 1.0000
# Epoch 40/50
# 5/5 [==============================] - 0s 7ms/step - loss: 0.3069 - acc: 0.8800 - recall: 1.0000 - val_loss: 0.3679 - val_acc: 0.9200 - val_recall: 1.0000
# Epoch 41/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.2839 - acc: 0.9200 - recall: 1.0000 - val_loss: 0.3365 - val_acc: 0.8200 - val_recall: 1.0000
# Epoch 42/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.2970 - acc: 0.9000 - recall: 1.0000 - val_loss: 0.3192 - val_acc: 0.8400 - val_recall: 1.0000
# Epoch 43/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.2663 - acc: 0.9000 - recall: 1.0000 - val_loss: 0.3993 - val_acc: 0.8000 - val_recall: 1.0000
# Epoch 44/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.2925 - acc: 0.8600 - recall: 1.0000 - val_loss: 0.3377 - val_acc: 0.9000 - val_recall: 0.9744
# Epoch 45/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.2714 - acc: 0.9000 - recall: 1.0000 - val_loss: 0.3374 - val_acc: 0.8200 - val_recall: 1.0000
# Epoch 46/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.3084 - acc: 0.9200 - recall: 1.0000 - val_loss: 0.3451 - val_acc: 0.8200 - val_recall: 1.0000
# Epoch 47/50
# 5/5 [==============================] - 0s 7ms/step - loss: 0.3510 - acc: 0.8400 - recall: 0.9474 - val_loss: 0.3119 - val_acc: 0.8600 - val_recall: 0.9744
# Epoch 48/50
# 5/5 [==============================] - 0s 8ms/step - loss: 0.2553 - acc: 0.8800 - recall: 1.0000 - val_loss: 0.3131 - val_acc: 0.9200 - val_recall: 1.0000
# Epoch 49/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.2486 - acc: 0.9000 - recall: 1.0000 - val_loss: 0.3400 - val_acc: 0.9200 - val_recall: 0.9487
# Epoch 50/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.2550 - acc: 0.9200 - recall: 1.0000 - val_loss: 0.3037 - val_acc: 0.8800 - val_recall: 1.0000

# %%
# Visualize the results
visualize_training_results(history, fsm, X_train, train_labels, X_val, val_labels)
# Out:
# Training eval:
# 2/2 [==============================] - 0s 1ms/step - loss: 0.2313 - acc: 0.9000 - recall: 1.0000
#
# Validation eval:
# 2/2 [==============================] - 0s 1ms/step - loss: 0.3037 - acc: 0.8800 - recall: 1.0000

# %% [markdown]
# **Analysis:**
# The accuracy and loss are unstable and the model is overfit, likely because:
#  - we are only training it on 50 images
#  - loss of data from resizing the images down to 100x100 from original sizes
#  - class imbalance (in favor of Pneumonia lungs)

# %% [markdown]
# ### Iteration

# %% [markdown]
# To improve on our first simple model, we iterated over several more models. The following model represents several collective improvements over these iterations, such as:
#  - Using the full dataset
#  - Resize to 256x256 in order to balance information retention and computational need
#  - Adding more Dense layers to improve the power of the network
#  - Using L2 regularization to avoid overfitting
#  - Using Adam optimizer function and specify learning rate to control stability during training
#  - Adding class weights to account for imbalanced classes distribution
#
# (To see the changes made for each individual iteration, see the code in our respective working notebooks.)

# %%
# Import and preprocess data
i5_X_train, i5_X_val, i5_train_labels, i5_val_labels = preprocess_dense_data(train_dir, batch_size=4000)
# Out:
# Found 4187 images belonging to 2 classes.
# Found 1045 images belonging to 2 classes.

# %%
# Calculate class weights
i5_class_weights = get_class_weights(i5_train_labels)

# %%
# Instatiate model
i5_model = models.Sequential()

# Add model layers - More layers and with l2 regularization
i5_model.add(Dense(32, activation='relu', input_shape=(256*256,)))
i5_model.add(Dense(20, activation='relu', kernel_regularizer=l2(l2=0.01)))
i5_model.add(Dense(18, activation='relu', kernel_regularizer=l2(l2=0.01)))
i5_model.add(Dense(16, activation='relu', kernel_regularizer=l2(l2=0.01)))
i5_model.add(Dense(12, activation='relu', kernel_regularizer=l2(l2=0.01)))
i5_model.add(Dense(8, activation='relu', kernel_regularizer=l2(l2=0.01)))
i5_model.add(Dense(4, activation='relu', kernel_regularizer=l2(l2=0.01)))
i5_model.add(Dense(1, activation='sigmoid', ))

# %%
# Compile
adam = Adam(lr=0.001)
i5_model.compile(optimizer=adam,
                 loss='binary_crossentropy',
                 metrics=['acc', 'Recall'])

# Train the model
i5_history = i5_model.fit(i5_X_train, i5_train_labels, 
                          epochs=100,
                          batch_size=32,
                          class_weight=i5_class_weights,
                          validation_data=(i5_X_val, i5_val_labels))
# Out:
# Epoch 1/100
# 125/125 [==============================] - 2s 20ms/step - loss: 1.4661 - acc: 0.2948 - recall: 0.0483 - val_loss: 1.1798 - val_acc: 0.5062 - val_recall: 0.3789
# Epoch 2/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.9094 - acc: 0.7903 - recall: 0.7671 - val_loss: 0.8820 - val_acc: 0.9081 - val_recall: 0.9149
# Epoch 3/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.6886 - acc: 0.9130 - recall: 0.9089 - val_loss: 0.7473 - val_acc: 0.8967 - val_recall: 0.8802
# Epoch 4/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.4945 - acc: 0.9308 - recall: 0.9288 - val_loss: 0.4204 - val_acc: 0.9301 - val_recall: 0.9369
# Epoch 5/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.4026 - acc: 0.9348 - recall: 0.9355 - val_loss: 0.4433 - val_acc: 0.9100 - val_recall: 0.9884
# Epoch 6/100
# 125/125 [==============================] - 2s 15ms/step - loss: 0.4473 - acc: 0.9090 - recall: 0.9099 - val_loss: 0.3839 - val_acc: 0.9254 - val_recall: 0.9214
# Epoch 7/100
# 125/125 [==============================] - 2s 15ms/step - loss: 0.3593 - acc: 0.9373 - recall: 0.9359 - val_loss: 0.3500 - val_acc: 0.9407 - val_recall: 0.9536
# Epoch 8/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.3157 - acc: 0.9523 - recall: 0.9501 - val_loss: 0.3458 - val_acc: 0.9311 - val_recall: 0.9291
# Epoch 9/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.3110 - acc: 0.9435 - recall: 0.9382 - val_loss: 0.3317 - val_acc: 0.9321 - val_recall: 0.9330
# Epoch 10/100
# 125/125 [==============================] - 2s 15ms/step - loss: 0.2907 - acc: 0.9523 - recall: 0.9511 - val_loss: 0.5509 - val_acc: 0.8411 - val_recall: 0.7861
# Epoch 11/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2918 - acc: 0.9480 - recall: 0.9460 - val_loss: 0.3077 - val_acc: 0.9349 - val_recall: 0.9381
# Epoch 12/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.2621 - acc: 0.9532 - recall: 0.9531 - val_loss: 0.3263 - val_acc: 0.9282 - val_recall: 0.9175
# Epoch 13/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.2490 - acc: 0.9595 - recall: 0.9588 - val_loss: 0.3773 - val_acc: 0.9120 - val_recall: 0.8879
# Epoch 14/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.2433 - acc: 0.9585 - recall: 0.9561 - val_loss: 0.3446 - val_acc: 0.9206 - val_recall: 0.9021
# Epoch 15/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.2455 - acc: 0.9540 - recall: 0.9504 - val_loss: 0.2599 - val_acc: 0.9483 - val_recall: 0.9626
# Epoch 16/100
# 125/125 [==============================] - 2s 15ms/step - loss: 0.2346 - acc: 0.9578 - recall: 0.9555 - val_loss: 0.3430 - val_acc: 0.9139 - val_recall: 0.8930
# Epoch 17/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.2660 - acc: 0.9410 - recall: 0.9366 - val_loss: 0.3310 - val_acc: 0.9167 - val_recall: 0.8943
# Epoch 18/100
# 125/125 [==============================] - 2s 15ms/step - loss: 0.2335 - acc: 0.9538 - recall: 0.9521 - val_loss: 0.3128 - val_acc: 0.9215 - val_recall: 0.9008
# Epoch 19/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.2108 - acc: 0.9565 - recall: 0.9541 - val_loss: 0.2569 - val_acc: 0.9435 - val_recall: 0.9768
# Epoch 20/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1970 - acc: 0.9660 - recall: 0.9642 - val_loss: 0.4960 - val_acc: 0.8545 - val_recall: 0.8041
# Epoch 21/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.2012 - acc: 0.9575 - recall: 0.9555 - val_loss: 0.2629 - val_acc: 0.9368 - val_recall: 0.9330
# Epoch 22/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.2123 - acc: 0.9557 - recall: 0.9541 - val_loss: 0.3417 - val_acc: 0.9110 - val_recall: 0.8853
# Epoch 23/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1939 - acc: 0.9597 - recall: 0.9575 - val_loss: 0.2333 - val_acc: 0.9493 - val_recall: 0.9704
# Epoch 24/100
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1680 - acc: 0.9710 - recall: 0.9693 - val_loss: 0.2411 - val_acc: 0.9445 - val_recall: 0.9459
# Epoch 25/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1810 - acc: 0.9605 - recall: 0.9598 - val_loss: 0.4011 - val_acc: 0.8938 - val_recall: 0.8582
# Epoch 26/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1833 - acc: 0.9613 - recall: 0.9595 - val_loss: 0.2408 - val_acc: 0.9378 - val_recall: 0.9369
# Epoch 27/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1622 - acc: 0.9697 - recall: 0.9673 - val_loss: 0.2252 - val_acc: 0.9493 - val_recall: 0.9601
# Epoch 28/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1829 - acc: 0.9575 - recall: 0.9565 - val_loss: 0.2240 - val_acc: 0.9464 - val_recall: 0.9536
# Epoch 29/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1595 - acc: 0.9700 - recall: 0.9676 - val_loss: 0.4147 - val_acc: 0.8900 - val_recall: 0.8544
# Epoch 30/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1906 - acc: 0.9545 - recall: 0.9517 - val_loss: 0.2736 - val_acc: 0.9292 - val_recall: 0.9149
# Epoch 31/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1468 - acc: 0.9712 - recall: 0.9676 - val_loss: 0.2566 - val_acc: 0.9340 - val_recall: 0.9253
# Epoch 32/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1697 - acc: 0.9597 - recall: 0.9585 - val_loss: 0.2127 - val_acc: 0.9483 - val_recall: 0.9716
# Epoch 33/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1480 - acc: 0.9700 - recall: 0.9676 - val_loss: 0.2145 - val_acc: 0.9445 - val_recall: 0.9549
# Epoch 34/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1443 - acc: 0.9700 - recall: 0.9686 - val_loss: 0.2480 - val_acc: 0.9359 - val_recall: 0.9291
# Epoch 35/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1434 - acc: 0.9722 - recall: 0.9703 - val_loss: 0.2290 - val_acc: 0.9426 - val_recall: 0.9420
# Epoch 36/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1492 - acc: 0.9690 - recall: 0.9679 - val_loss: 0.2163 - val_acc: 0.9426 - val_recall: 0.9523
# Epoch 37/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1339 - acc: 0.9737 - recall: 0.9737 - val_loss: 0.3098 - val_acc: 0.9167 - val_recall: 0.8943
# Epoch 38/100
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1728 - acc: 0.9553 - recall: 0.9528 - val_loss: 0.2459 - val_acc: 0.9301 - val_recall: 0.9137
# Epoch 39/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1317 - acc: 0.9722 - recall: 0.9700 - val_loss: 0.2594 - val_acc: 0.9321 - val_recall: 0.9175
# Epoch 40/100
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1639 - acc: 0.9557 - recall: 0.9521 - val_loss: 0.2103 - val_acc: 0.9435 - val_recall: 0.9472
# Epoch 41/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1578 - acc: 0.9567 - recall: 0.9541 - val_loss: 0.2288 - val_acc: 0.9368 - val_recall: 0.9343
# Epoch 42/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1178 - acc: 0.9778 - recall: 0.9777 - val_loss: 0.2365 - val_acc: 0.9368 - val_recall: 0.9317
# Epoch 43/100
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1124 - acc: 0.9790 - recall: 0.9777 - val_loss: 0.2695 - val_acc: 0.9311 - val_recall: 0.9201
# Epoch 44/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1284 - acc: 0.9718 - recall: 0.9713 - val_loss: 0.2397 - val_acc: 0.9388 - val_recall: 0.9304
# Epoch 45/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1245 - acc: 0.9720 - recall: 0.9693 - val_loss: 0.2031 - val_acc: 0.9435 - val_recall: 0.9497
# Epoch 46/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1162 - acc: 0.9768 - recall: 0.9754 - val_loss: 0.2184 - val_acc: 0.9483 - val_recall: 0.9729
# Epoch 47/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1117 - acc: 0.9765 - recall: 0.9733 - val_loss: 0.2260 - val_acc: 0.9426 - val_recall: 0.9420
# Epoch 48/100
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1266 - acc: 0.9715 - recall: 0.9700 - val_loss: 0.2495 - val_acc: 0.9368 - val_recall: 0.9278
# Epoch 49/100
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1062 - acc: 0.9783 - recall: 0.9757 - val_loss: 0.2086 - val_acc: 0.9435 - val_recall: 0.9575
# Epoch 50/100
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1068 - acc: 0.9787 - recall: 0.9757 - val_loss: 0.2087 - val_acc: 0.9455 - val_recall: 0.9575
# Epoch 51/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1365 - acc: 0.9657 - recall: 0.9646 - val_loss: 0.1911 - val_acc: 0.9512 - val_recall: 0.9626
# Epoch 52/100
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1093 - acc: 0.9753 - recall: 0.9747 - val_loss: 0.3955 - val_acc: 0.8900 - val_recall: 0.8544
# Epoch 53/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1294 - acc: 0.9675 - recall: 0.9656 - val_loss: 0.2220 - val_acc: 0.9435 - val_recall: 0.9807
# Epoch 54/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1085 - acc: 0.9762 - recall: 0.9750 - val_loss: 0.1997 - val_acc: 0.9474 - val_recall: 0.9652
# Epoch 55/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.0893 - acc: 0.9858 - recall: 0.9841 - val_loss: 0.2099 - val_acc: 0.9416 - val_recall: 0.9497
# Epoch 56/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.0894 - acc: 0.9860 - recall: 0.9841 - val_loss: 0.3139 - val_acc: 0.9187 - val_recall: 0.8969
# Epoch 57/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1306 - acc: 0.9707 - recall: 0.9679 - val_loss: 0.1857 - val_acc: 0.9455 - val_recall: 0.9562
# Epoch 58/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.0897 - acc: 0.9837 - recall: 0.9821 - val_loss: 0.2520 - val_acc: 0.9340 - val_recall: 0.9240
# Epoch 59/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1399 - acc: 0.9605 - recall: 0.9571 - val_loss: 0.3669 - val_acc: 0.8986 - val_recall: 0.8673
# Epoch 60/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0943 - acc: 0.9820 - recall: 0.9791 - val_loss: 0.2289 - val_acc: 0.9416 - val_recall: 0.9381
# Epoch 61/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1154 - acc: 0.9705 - recall: 0.9676 - val_loss: 0.2101 - val_acc: 0.9426 - val_recall: 0.9420
# Epoch 62/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0877 - acc: 0.9818 - recall: 0.9798 - val_loss: 0.2145 - val_acc: 0.9455 - val_recall: 0.9472
# Epoch 63/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.0914 - acc: 0.9812 - recall: 0.9784 - val_loss: 0.2155 - val_acc: 0.9464 - val_recall: 0.9794
# Epoch 64/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.0764 - acc: 0.9877 - recall: 0.9855 - val_loss: 0.2332 - val_acc: 0.9435 - val_recall: 0.9446
# Epoch 65/100
# 125/125 [==============================] - 2s 15ms/step - loss: 0.0920 - acc: 0.9810 - recall: 0.9781 - val_loss: 0.5407 - val_acc: 0.8612 - val_recall: 0.8131
# Epoch 66/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1592 - acc: 0.9607 - recall: 0.9585 - val_loss: 0.3158 - val_acc: 0.9139 - val_recall: 0.8905
# Epoch 67/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.0825 - acc: 0.9872 - recall: 0.9852 - val_loss: 0.2273 - val_acc: 0.9426 - val_recall: 0.9497
# Epoch 68/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1142 - acc: 0.9720 - recall: 0.9696 - val_loss: 0.1972 - val_acc: 0.9493 - val_recall: 0.9716
# Epoch 69/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.0958 - acc: 0.9805 - recall: 0.9781 - val_loss: 0.2195 - val_acc: 0.9455 - val_recall: 0.9497
# Epoch 70/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.0851 - acc: 0.9865 - recall: 0.9862 - val_loss: 0.6751 - val_acc: 0.8316 - val_recall: 0.7732
# Epoch 71/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.0944 - acc: 0.9805 - recall: 0.9774 - val_loss: 0.2231 - val_acc: 0.9407 - val_recall: 0.9446
# Epoch 72/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0923 - acc: 0.9803 - recall: 0.9791 - val_loss: 0.2813 - val_acc: 0.9244 - val_recall: 0.9059
# Epoch 73/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0770 - acc: 0.9868 - recall: 0.9848 - val_loss: 0.2513 - val_acc: 0.9416 - val_recall: 0.9369
# Epoch 74/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.0691 - acc: 0.9920 - recall: 0.9906 - val_loss: 0.2156 - val_acc: 0.9435 - val_recall: 0.9523
# Epoch 75/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0791 - acc: 0.9852 - recall: 0.9848 - val_loss: 0.2090 - val_acc: 0.9435 - val_recall: 0.9510
# Epoch 76/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1015 - acc: 0.9758 - recall: 0.9750 - val_loss: 0.2542 - val_acc: 0.9263 - val_recall: 0.9098
# Epoch 77/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0881 - acc: 0.9810 - recall: 0.9791 - val_loss: 0.1985 - val_acc: 0.9445 - val_recall: 0.9613
# Epoch 78/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0761 - acc: 0.9875 - recall: 0.9855 - val_loss: 0.2077 - val_acc: 0.9455 - val_recall: 0.9639
# Epoch 79/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0713 - acc: 0.9885 - recall: 0.9872 - val_loss: 0.2478 - val_acc: 0.9359 - val_recall: 0.9291
# Epoch 80/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.0773 - acc: 0.9852 - recall: 0.9831 - val_loss: 0.2273 - val_acc: 0.9426 - val_recall: 0.9407
# Epoch 81/100
# 125/125 [==============================] - 2s 15ms/step - loss: 0.0669 - acc: 0.9927 - recall: 0.9916 - val_loss: 0.2781 - val_acc: 0.9368 - val_recall: 0.9253
# Epoch 82/100
# 125/125 [==============================] - 2s 15ms/step - loss: 0.0759 - acc: 0.9875 - recall: 0.9858 - val_loss: 0.2484 - val_acc: 0.9378 - val_recall: 0.9278
# Epoch 83/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.0782 - acc: 0.9858 - recall: 0.9831 - val_loss: 0.1953 - val_acc: 0.9464 - val_recall: 0.9601
# Epoch 84/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.0640 - acc: 0.9912 - recall: 0.9902 - val_loss: 0.2270 - val_acc: 0.9455 - val_recall: 0.9755
# Epoch 85/100
# 125/125 [==============================] - 2s 15ms/step - loss: 0.0613 - acc: 0.9942 - recall: 0.9933 - val_loss: 0.2979 - val_acc: 0.9254 - val_recall: 0.9072
# Epoch 86/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.0985 - acc: 0.9787 - recall: 0.9760 - val_loss: 0.2172 - val_acc: 0.9435 - val_recall: 0.9446
# Epoch 87/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.0608 - acc: 0.9923 - recall: 0.9909 - val_loss: 0.4723 - val_acc: 0.8909 - val_recall: 0.8557
# Epoch 88/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1265 - acc: 0.9680 - recall: 0.9666 - val_loss: 0.5322 - val_acc: 0.8526 - val_recall: 0.8015
# Epoch 89/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0871 - acc: 0.9815 - recall: 0.9787 - val_loss: 0.1891 - val_acc: 0.9464 - val_recall: 0.9549
# Epoch 90/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.0747 - acc: 0.9845 - recall: 0.9835 - val_loss: 0.2085 - val_acc: 0.9435 - val_recall: 0.9472
# Epoch 91/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.0570 - acc: 0.9940 - recall: 0.9922 - val_loss: 0.2467 - val_acc: 0.9378 - val_recall: 0.9832
# Epoch 92/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1571 - acc: 0.9525 - recall: 0.9477 - val_loss: 0.1888 - val_acc: 0.9502 - val_recall: 0.9704
# Epoch 93/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0619 - acc: 0.9910 - recall: 0.9892 - val_loss: 0.2040 - val_acc: 0.9474 - val_recall: 0.9588
# Epoch 94/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0610 - acc: 0.9920 - recall: 0.9906 - val_loss: 0.2152 - val_acc: 0.9435 - val_recall: 0.9485
# Epoch 95/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.0594 - acc: 0.9923 - recall: 0.9909 - val_loss: 0.2117 - val_acc: 0.9464 - val_recall: 0.9588
# Epoch 96/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.0595 - acc: 0.9918 - recall: 0.9899 - val_loss: 0.2376 - val_acc: 0.9464 - val_recall: 0.9433
# Epoch 97/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.0556 - acc: 0.9940 - recall: 0.9933 - val_loss: 0.3465 - val_acc: 0.9158 - val_recall: 0.8918
# Epoch 98/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.0881 - acc: 0.9797 - recall: 0.9777 - val_loss: 0.1951 - val_acc: 0.9445 - val_recall: 0.9601
# Epoch 99/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.0768 - acc: 0.9840 - recall: 0.9835 - val_loss: 0.1978 - val_acc: 0.9464 - val_recall: 0.9601
# Epoch 100/100
# 125/125 [==============================] - 2s 15ms/step - loss: 0.0536 - acc: 0.9950 - recall: 0.9936 - val_loss: 0.2159 - val_acc: 0.9445 - val_recall: 0.9562

# %%
visualize_training_results(i5_history, i5_model, i5_X_train, i5_train_labels, i5_X_val, i5_val_labels)
# Out:
# Training eval:
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0501 - acc: 0.9967 - recall: 0.9960
#
# Validation eval:
# 33/33 [==============================] - 0s 5ms/step - loss: 0.2159 - acc: 0.9445 - recall: 0.9562

# %% [markdown]
# Our changes to the model both reduced overfitting and increased performance on recall and general accuracy, bringing accuracy up to 94.5% and recall to 95.6%.
#
# Despite iterative improvements, our models using only fully connected Dense layers hit a ceiling around 95% for accuracy and recall on the validation set. We decided to add convolutional layers in order to continue improving the model. The hope is that the model will identify more granular patterns in the data by using convolutional layers with filters and pooling layers.

# %% [markdown]
# ### First CNN model

# %% [markdown]
# We add a new `preprocess` function that returns the `train_generator` and `val_generator` rather than an array of images as we no longer have to reshape/flatten the images before feeding them into the model. This will also allows us to more easily use the full dataset in training. For our first CNN model we have used an architecture from the Flatiron curriculum as a starting point.
#
# **Note:** While the Dense models fit in a matter of minutes or even seconds, the CNN models often take a couple hours to fit. As a result, we have saved some models as `'*.h5'` files and reloaded some of them into this notebook rather than refitting them. The original code for each model can be found in our respective working notebooks.

# %%
# Preprocess the data
train_gen_1, val_gen_1 = preprocess_cnn_data(train_dir, batch_size=50)
# Out:
# Found 4187 images belonging to 2 classes.
# Found 1045 images belonging to 2 classes.

# %%
# Get the class weights
class_weights_1 = get_class_weights(train_gen_1.classes)
class_weights_1
# Out:
# {0: 1.938425925925926, 1: 0.6738010943031864}

# %%
# Instatiate model
cnn_model_1 = models.Sequential()

# Add model layers - Using architecture from Canvas 'CNN from Scratch - Lab' to start
cnn_model_1.add(Conv2D(32, (3, 3), activation='relu', input_shape=(256, 256, 1)))
cnn_model_1.add(MaxPooling2D((2, 2)))
cnn_model_1.add(Conv2D(64, (3, 3), activation='relu'))
cnn_model_1.add(MaxPooling2D((2, 2)))
cnn_model_1.add(Conv2D(128, (3, 3), activation='relu'))
cnn_model_1.add(MaxPooling2D((2, 2)))
cnn_model_1.add(Conv2D(128, (3, 3), activation='relu'))
cnn_model_1.add(MaxPooling2D((2, 2)))
# Flatten
cnn_model_1.add(Flatten())
# Final Dense layers
cnn_model_1.add(Dense(512, activation='relu'))
cnn_model_1.add(Dense(1, activation='sigmoid'))

# Compile
cnn_model_1.compile(optimizer='rmsprop',
                    loss='binary_crossentropy',
                    metrics=['acc', 'Recall'])

# %%
# Train the model
history_1 = cnn_model_1.fit(train_gen_1,
                            steps_per_epoch=40, 
                            epochs=15, 
                            validation_data=val_gen_1, 
                            class_weight=class_weights_1,
                            validation_steps=20)
# Out:
# Epoch 1/15
# 40/40 [==============================] - 150s 4s/step - loss: 0.7217 - acc: 0.6940 - recall: 0.6810 - val_loss: 0.3823 - val_acc: 0.8480 - val_recall: 0.8482
# Epoch 2/15
# 40/40 [==============================] - 150s 4s/step - loss: 0.3577 - acc: 0.8596 - recall: 0.8494 - val_loss: 0.2793 - val_acc: 0.8760 - val_recall: 0.8851
# Epoch 3/15
# 40/40 [==============================] - 150s 4s/step - loss: 0.2392 - acc: 0.9074 - recall: 0.9040 - val_loss: 0.2059 - val_acc: 0.9290 - val_recall: 0.9248
# Epoch 4/15
# 40/40 [==============================] - 151s 4s/step - loss: 0.1534 - acc: 0.9370 - recall: 0.9315 - val_loss: 0.2184 - val_acc: 0.9200 - val_recall: 0.9685
# Epoch 5/15
# 40/40 [==============================] - 156s 4s/step - loss: 0.1434 - acc: 0.9450 - recall: 0.9439 - val_loss: 0.2698 - val_acc: 0.9100 - val_recall: 0.9822
# Epoch 6/15
# 40/40 [==============================] - 157s 4s/step - loss: 0.1506 - acc: 0.9480 - recall: 0.9468 - val_loss: 0.2114 - val_acc: 0.9390 - val_recall: 0.9781
# Epoch 7/15
# 40/40 [==============================] - 154s 4s/step - loss: 0.1199 - acc: 0.9567 - recall: 0.9552 - val_loss: 0.2683 - val_acc: 0.9230 - val_recall: 0.9029
# Epoch 8/15
# 40/40 [==============================] - 150s 4s/step - loss: 0.0771 - acc: 0.9715 - recall: 0.9670 - val_loss: 1.0638 - val_acc: 0.8070 - val_recall: 0.9973
# Epoch 9/15
# 40/40 [==============================] - 153s 4s/step - loss: 0.1140 - acc: 0.9685 - recall: 0.9699 - val_loss: 0.1394 - val_acc: 0.9490 - val_recall: 0.9713
# Epoch 10/15
# 40/40 [==============================] - 151s 4s/step - loss: 0.1044 - acc: 0.9650 - recall: 0.9671 - val_loss: 0.2056 - val_acc: 0.9400 - val_recall: 0.9781
# Epoch 11/15
# 40/40 [==============================] - 152s 4s/step - loss: 0.0486 - acc: 0.9805 - recall: 0.9798 - val_loss: 0.3307 - val_acc: 0.9250 - val_recall: 0.9083
# Epoch 12/15
# 40/40 [==============================] - 145s 4s/step - loss: 0.0575 - acc: 0.9789 - recall: 0.9768 - val_loss: 0.1888 - val_acc: 0.9610 - val_recall: 0.9658
# Epoch 13/15
# 40/40 [==============================] - 149s 4s/step - loss: 0.0650 - acc: 0.9780 - recall: 0.9771 - val_loss: 0.1914 - val_acc: 0.9520 - val_recall: 0.9412
# Epoch 14/15
# 40/40 [==============================] - 154s 4s/step - loss: 0.0449 - acc: 0.9834 - recall: 0.9817 - val_loss: 0.2161 - val_acc: 0.9620 - val_recall: 0.9685
# Epoch 15/15
# 40/40 [==============================] - 146s 4s/step - loss: 0.0644 - acc: 0.9804 - recall: 0.9797 - val_loss: 0.2180 - val_acc: 0.9560 - val_recall: 0.9549

# %%
visualize_results_cnn(history_1, cnn_model_1, train_gen_1, val_gen_1)
# Out:
# Training eval:
# 84/84 [==============================] - 76s 909ms/step - loss: 0.0340 - acc: 0.9852 - recall: 0.9813
#
# Validation eval:
# 21/21 [==============================] - 18s 847ms/step - loss: 0.2087 - acc: 0.9579 - recall: 0.9575

# %% [markdown]
# This first CNN model improved on both accuracy and recall on the validation set. However, it is still leaving more false-negatives than we would want and as we continue to iterate we will focus on bringing up recall, even at the cost of accuracy. False positives have potentially fewer serious consequences (continued observation, more testing) than false negatives (untreated disease and fatality), especially with pediatric patients.

# %% [markdown]
# ### Further CNN iterations

# %% [markdown]
# We continued to iterate with CNN models, adjusting various layers and parameters, including:
#  - Introducing `BatchNormalization` layers, which reduce the range of input values to speed training and improve performance
#  - Adding L2 regularization to avoid overfitting
#  - Adjusting number of layers to change the complexity of the model
#  - Reducing number of epochs to potentially avoid overfitting
#  - Increasing kernel (filter) size from (3, 3) to (5, 5)

# %% [markdown]
# Collectively, we iterated on over a dozen models, adjusting these parameters among others. The following is one example of this iterative process; the others can be seen in our working notebooks.

# %%
cnn_model_4 = models.load_model('models/cnn_model_4.h5')

# %%
# Load and preprocess the data
train_gen_4, val_gen_4 = preprocess_cnn_data(train_dir, batch_size=50)
# Out:
# Found 4187 images belonging to 2 classes.
# Found 1045 images belonging to 2 classes.

# %%
# Display model architecture
cnn_model_4.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_33 (Conv2D)           (None, 254, 254, 32)      320
# _________________________________________________________________
# max_pooling2d_32 (MaxPooling (None, 127, 127, 32)      0
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 123, 123, 64)      51264
# _________________________________________________________________
# max_pooling2d_33 (MaxPooling (None, 61, 61, 64)        0
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 57, 57, 128)       204800
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 57, 57, 128)       512
# _________________________________________________________________
# activation_4 (Activation)    (None, 57, 57, 128)       0
# _________________________________________________________________
# max_pooling2d_34 (MaxPooling (None, 28, 28, 128)       0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 100352)            0
# _________________________________________________________________
# dense_22 (Dense)             (None, 512)               51380736
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 51,638,145
# Trainable params: 51,637,889
# Non-trainable params: 256
# _________________________________________________________________

# %%
# Display metrics and evaluation
cnn_model_4.evaluate(train_gen_4)
# Out:
# 84/84 [==============================] - 103s 1s/step - loss: 0.0020 - acc: 0.9995 - recall: 0.9994
# [0.002024430315941572, 0.99952232837677, 0.9993562698364258]

# %%
cnn_model_4.evaluate(val_gen_4)
# Out:
# 21/21 [==============================] - 22s 1s/step - loss: 0.1099 - acc: 0.9742 - recall: 0.9716
# [0.10985701531171799, 0.9741626977920532, 0.9716494679450989]

# %%
# Confusion matrix for validation set
y_val_preds = (cnn_model_4.predict(val_gen_4) > 0.5).astype('int32')
ConfusionMatrixDisplay(confusion_matrix(val_gen_4.labels, y_val_preds),
                       display_labels=['Val_Normal', 'Val_Pneumonia']).plot();

# %% [markdown]
# This model has a validation accuracy of 97.42% and recall of 97.16%. The confusion matrix shows that there are significantly more false negatives than false positives. For reasons discussed above, we want to reduce false negatives as much as possible while maintaining decent accuracy, even at the expense of false postiives.

# %% [markdown]
# ### Best CNN model

# %% [markdown]
# After iterating through many different models, we decided on the following model as our final best model based on validation scores.

# %%
final_model = models.load_model('models/final_model.h5')

# %%
# Load and preprocess the data
train_gen_5, val_gen_5, test_gen_5 = preprocess_cnn_data(train_dir, test_dir, batch_size=50)
# Out:
# Found 4187 images belonging to 2 classes.
# Found 1045 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %%
final_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 254, 254, 32)      320
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 127, 127, 32)      0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 123, 123, 64)      51264
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 61, 61, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 57, 57, 128)       204800
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 57, 57, 128)       512
# _________________________________________________________________
# activation_2 (Activation)    (None, 57, 57, 128)       0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 28, 28, 128)       0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 100352)            0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               51380736
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 51,638,145
# Trainable params: 51,637,889
# Non-trainable params: 256
# _________________________________________________________________

# %%
final_model.evaluate(train_gen_5)
# Out:
# 84/84 [==============================] - 533s 6s/step - loss: 0.1732 - accuracy: 0.9809 - recall: 0.9762
# [0.17318978905677795, 0.9808932542800903, 0.9761828184127808]

# %%
final_model.evaluate(val_gen_5)
# Out:
# 21/21 [==============================] - 128s 6s/step - loss: 0.2110 - accuracy: 0.9617 - recall: 0.9562
# [0.21095222234725952, 0.9617224931716919, 0.9561855792999268]

# %%
final_model.evaluate(test_gen_5)
# Out:
# 13/13 [==============================] - 47s 4s/step - loss: 0.7125 - accuracy: 0.8093 - recall: 0.9846
# [0.7124913334846497, 0.8092948794364929, 0.9846153855323792]

# %%
y_test_preds = (final_model.predict(test_gen_5) > 0.5).astype('int32')
ConfusionMatrixDisplay(confusion_matrix(test_gen_5.labels, y_test_preds),
                       display_labels=['Test_Normal', 'Test_Pneumonia']).plot();

# %% [markdown]
# #### Exploring the model

# %% [markdown]
# In order to confirm the model is analyzing truly important data (i.e., the lungs in the CXR and not other unimportant or irrelevant factors, such as the 'R' on the image), we visualize the intermediate layers of the model. This allows us to peer into the "black box" that is the CNN model, revealing the patterns in the images that each filter is attending to.

# %%
img_path = 'chest_xray/test/PNEUMONIA/person1_virus_6.jpeg'
img_path2 = 'chest_xray/test/NORMAL/IM-0006-0001.jpeg'


img = image.load_img(img_path, color_mode='grayscale', target_size=(256, 256))
img_tensor = image.img_to_array(img)
img_tensor = np.expand_dims(img_tensor, axis=0)

img2 = image.load_img(img_path2, color_mode='grayscale', target_size=(256, 256))
img_tensor2 = image.img_to_array(img2)
img_tensor2 = np.expand_dims(img_tensor2, axis=0)

#Follow the Original Model Preprocessing
img_tensor /= 255.

img_tensor2 /= 255.

#Check tensor shape
print(img_tensor.shape)

#Preview an image
plt.imshow(img_tensor[0], cmap='gray')
plt.show()
# Out:
# (1, 256, 256, 1)

# %%
# Extract model layer outputs
layer_outputs = [layer.output for layer in final_model.layers[:8]]

# Rather then a model with a single output, we are going to make a model to display the feature maps
activation_model = models.Model(inputs=final_model.input, outputs=layer_outputs)

activations = activation_model.predict(img_tensor)

# %%
fig, axes = plt.subplots(8, 4, figsize=(12,24))
for i in range(32):
    row = i//4
    column = i%4
    ax = axes[row, column]
    first_layer_activation = activations[0]
    ax.matshow(first_layer_activation[0, :, :, i], cmap='gray')

# %%
# Returns an array for each activation layer
fig, axes = plt.subplots(2,4, figsize=(12,8))

layer_names = []
for layer in final_model.layers[:8]:
    layer_names.append(layer.name)

for i in range(8):
    row = i//4
    column = i%4
    ax = axes[row, column]
    cur_layer = activations[i]
    ax.matshow(cur_layer[0, :, :, 30], cmap='gray')
    ax.xaxis.set_ticks_position('bottom')
    ax.set_title(layer_names[i])

# %%
activations2 = activation_model.predict(img_tensor2)

fig, axes = plt.subplots(8, 4, figsize=(12,24))
for i in range(32):
    row = i//4
    column = i%4
    ax = axes[row, column]
    first_layer_activation = activations2[0]
    ax.matshow(first_layer_activation[0, :, :, i], cmap='gray')

# %%
fig, axes = plt.subplots(2,4, figsize=(12,8))

layer_names = []
for layer in final_model.layers[:8]:
    layer_names.append(layer.name)

for i in range(8):
    row = i//4
    column = i%4
    ax = axes[row, column]
    cur_layer2 = activations2[i]
    ax.matshow(cur_layer2[0, :, :, 4], cmap='gray')
    ax.xaxis.set_ticks_position('bottom')
    ax.set_title(layer_names[i])

# %% [markdown]
# #### Examining misclassified images

# %% [markdown]
# We also want to visually inspect the misclassified images in order to verify that there are no obvious confounding variables or patterns interfering with the performance of the model.

# %% [markdown]
# ## Final Evaluation

# %% [markdown]
# ## Recommendations and Next Steps

# %% [markdown]
# ### Thank you!
